# %%
import numpy as np
import skimage 
astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)

skimage.io.imshow(astronaut)
skimage.io.show()
skimage.io.imshow(rocket)
skimage.io.show()
(512, 512, 3)
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (512, 512, 3)

# %%
import numpy as np
import skimage 
astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)


image=skimage.data.astronaut()
from skimage.util import crop
image1 = image[0:427,0:512,:]
image2=rocket[0:427,0:512,:]
print(image2.shape)


skimage.io.imshow(image1)
skimage.io.show()
skimage.io.imshow(image2)
skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (427, 512, 3)

# %%
# Exercise 2
# Use "numpy concatenate" to create the following image:
import numpy as np
import skimage 

astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)


image=skimage.data.astronaut()
from skimage.util import crop
image1 = image[0:427,0:512,:]
image2=rocket[0:427,0:512,:]
print(image2.shape)


#merge = np.concatenate((image1,image2))

# sf_collection = (image1,image2)
# concat_page = skimage.io.concatenate_images(sf_collection)

# skimage.io.imshow(concat_page)
# skimage.io.show()



arr1 = np.array(image1)

arr2 = np.array(image2)

arr = np.concatenate((image1,image2),axis=1)
skimage.io.imshow(arr)
skimage.io.show()

# images = [arr1,arr2]
# output = concat_n_images(images)

# skimage.io.imshow(images)
# skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (427, 512, 3)

# %%
import numpy as np
import skimage 

astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)


image=skimage.data.astronaut()
from skimage.util import crop
image1 = image[0:427,0:512,:]
image2=rocket[0:427,0:512,:]
print(image2.shape)

arr1 = np.array(image1)

arr2 = np.array(image2)

arr = np.concatenate((image1,image2),axis=1)

exercise3 = np.concatenate((arr,arr),axis=0)


skimage.io.imshow(exercise3)
skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (427, 512, 3)

# %%
#flip the image
import numpy as np
import skimage 

astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)


image=skimage.data.astronaut()
from skimage.util import crop
image1 = image[0:427,0:512,:]
image2=rocket[0:427,0:512,:]
print(image2.shape)




arr1 = np.array(image1)

arr2 = np.array(image2)

arr = np.concatenate((image1,image2),axis=1)
print(arr.shape)
exercise4=np.flip(arr,0)
skimage.io.imshow(exercise4)
skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (427, 512, 3)
# (427, 1024, 3)

# %%
# Exercise 2
# Use "numpy concatenate" to create the following image:
import numpy as np
import skimage 

astronaut = skimage.data.astronaut()
rocket = skimage.data.rocket()


print(astronaut.shape)
print(rocket.shape)


image=skimage.data.astronaut()
from skimage.util import crop
image1 = image[0:427,0:512,:]
image2=rocket[0:427,0:512,:]
print(image2.shape)

arr1 = np.array(image1)

arr2 = np.array(image2)

arr = np.concatenate((image1,image2),axis=1)
exercise4=np.flip(arr,1)

exercise5=np.concatenate((arr,exercise4),axis=0)

skimage.io.imshow(exercise5)
skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)
# (427, 512, 3)

# %%
# Exercise 6
# use skimage-library to convert RGB-image to grayscale

# random_image=np.random.random([500,500])

# plt.imshow(random_image,cmap='winter')
# plt.colorbar();

import numpy as np
import skimage 
from skimage.color import rgb2gray
from skimage import filters

astronaut = skimage.data.astronaut()


print(astronaut.shape)
print(rocket.shape)
original = skimage.data.astronaut()
grayscale = rgb2gray(original)
skimage.io.imshow(grayscale)
skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)

# %%
import numpy as np
import skimage 
from skimage.color import rgb2gray
from skimage.filters import threshold_mean
import matplotlib as plt


astronaut = skimage.data.astronaut()


print(astronaut.shape)
print(rocket.shape)
original = skimage.data.astronaut()
grayscale = rgb2gray(original)
skimage.io.imshow(grayscale)
skimage.io.show()

from skimage.filters import try_all_threshold



# Here, we specify a radius for local thresholding algorithms.
# If it is not specified, only global algorithms are called.
fig, ax = try_all_threshold(grayscale,figsize=(10, 8), verbose=False)

skimage.io.show()
# Out:
# (512, 512, 3)
# (427, 640, 3)

# %%
import numpy as np
import skimage 
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu
from skimage.filters import try_all_threshold



astronaut = skimage.data.astronaut()


print(astronaut.shape)
print(rocket.shape)
original = skimage.data.astronaut()
grayscale = rgb2gray(original)
skimage.io.imshow(grayscale)
skimage.io.show()


thresh = threshold_otsu(grayscale)
binary = grayscale > thresh
skimage.io.imshow(binary)
# Out:
# (512, 512, 3)
# (427, 640, 3)

# %%
#inverted threshold
import numpy as np
import skimage 
from skimage.color import rgb2gray
from skimage.filters import threshold_otsu
from skimage.filters import try_all_threshold



astronaut = skimage.data.astronaut()


print(astronaut.shape)
print(rocket.shape)
original = skimage.data.astronaut()
grayscale = rgb2gray(original)
skimage.io.imshow(grayscale)
skimage.io.show()


thresh = threshold_otsu(grayscale)
binary = grayscale <= thresh
skimage.io.imshow(binary)
# Out:
# (512, 512, 3)
# (427, 640, 3)

# %%
# Exercise 8
# Find out the best tool/method to make the astronaut-image "negative"
from skimage.io import imread
import numpy as np
import skimage 
from skimage.color import rgb2gray
from skimage import filters

astronaut = skimage.data.astronaut()


padded_image = np.ndarray(shape=astronaut.shape)
for i in range(0, image.shape[0]):
    for j in range(0, image.shape[1]):
        padded_image[i][j] = image[i][j]
skimage.io.show(padded_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-48b34a1af240> in <module>
#      14     for j in range(0, image.shape[1]):
#      15         padded_image[i][j] = image[i][j]
# ---> 16 skimage.io.show(padded_image)
#
# TypeError: show() takes 0 positional arguments but 1 was given
