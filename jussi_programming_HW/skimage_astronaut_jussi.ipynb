# %%
import numpy as np
import skimage 
image = skimage.data.astronaut()
skimage.io.imshow(image)

# %%
image=skimage.data.astronaut()
from skimage.util import crop
face = image[0:200,140:300,:]

skimage.io.imshow(face)
skimage.io.show()

# %%
eye = face[85:110,50:75]

skimage.io.imshow(eye)
skimage.io.show()

# %%
eye[15:18,12:15]=[255,0,0]
skimage.io.imshow(eye)
skimage.io.show()

# %%
# image=skimage.data.astronaut()
import numpy as np
import skimage 
image = skimage.data.astronaut()
skimage.io.imshow(image)
image[10:31,50:71]=[255,102,178]
image[31:51,50:71]=[255,153,255]
image[51:71,50:71]=[255,51,255]
image[71:91,50:71]=[204,0,204]
image[91:111,50:71]=[153,0,153]
image[111:131,50:71]=[102,0,102]
image[131:151,50:71]=[51,0,51]
# image[151:171,50:71]=[255,102,255]
# image[171:191,50:71]=[255,153,255]

image[10:31,71:91]=[255,51,153]
image[10:31,91:111]=[255,102,178]
image[10:31,111:131]=[255,0,255]

image[31:51,111:131]=[255,102,255]
image[51:71,111:131]=[255,51,255]
image[51:71,91:111]=[204,0,204]
image[51:71,71:91]=[51,0,51]

image[10:31,320:361]=[204,0,204]
image[31:51,320:341]=[127,0,255]
image[51:71,320:341]=[178,102,255]
image[71:91,320:341]=[153,51,255]
image[91:111,320:341]=[255,10,255]
image[111:131,320:341]=[255,102,178]
image[131:151,320:341]=[127,0,255]


image[31:51,351:371]=[127,0,255]
image[51:71,361:381]=[178,102,255]
image[71:91,371:391]=[255,102,255]
image[91:111,381:401]=[255,0,127]
image[111:131,391:411]=[255,102,178]
image[131:151,401:411]=[255,0,127]

image[111:151,411:421]=[255,0,127]
image[91:111,401:421]=[255,102,178]
image[71:91,401:421]=[178,102,255]
image[51:71,401:421]=[204,0,204]
image[31:51,401:421]=[178,102,255]
image[10:31,401:421]=[255,0,127]



skimage.io.imshow(image)
skimage.io.show()
