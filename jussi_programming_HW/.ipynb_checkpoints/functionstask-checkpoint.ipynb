# %%
def welcome():
    user_name=input("May I know your name?")
    print("Hello",user_name)
    ask_topic(user_name)
def ask_topic(user_name):
    topic=input("%s ,Would you like to hear about pop ,rock or classical or neo classical?"%user_name)
    if topic=="pop":
        pop(user_name)
    if topic=="rock":
        rock(user_name)
    if topic=="classical":
        classical(user_name)
    if topic=="neo classical":
        neo_classical(user_name)
        
def pop(user_name):
    print("%s,Pop music is  what is considered to be popular that is originated in it's modern form during the mid-1950s.\n For instance : All about that bass,Meghan Trainor"%user_name)
    list1=["yes","sure","for sure","ok","cool","thanks","thank you"]
    list2=["no","no,thanks","I don´t want to "]
    answer=input("%s,Would you like to know about neo classical as well?"%user_name)
    if answer in  list1:
        neo_classical(user_name)
    if answer in  list2:
        choise=input("%s,Do you want to change topic or leave"%user_name)
        if choise=="change topic":
            ask_topic(user_name)
        if choise=="Leave" or "leave":
            goodbye(user_name)
    if answer not in list1:
        neo_classical(user_name)
def rock(user_name):
    print("%s,Rock sounds like a good topic\n It developed during after the 1960s in United States and originally started in 1940s."%user_name)
    list=["yes","sure","for sure","ok","cool","thanks","thank you"]
    list0=["no","no,thanks","I don´t want to "]
    answer1=input("%s,Would you like to know about neo classical?"%user_name)
    if answer1 in list:
        neo_classical(user_name)
    if answer1 in list0:
        choise1=input("%s,Do you want to change topic or leave"%user_name)
        if choise1=="change topic" "Change topic":
            ask_topic(user_name)
        if choise1=="Leave" or "leave":
            goodbye(user_name)
    
def classical(user_name):
    print("%s,classical music is noted for it´s development of highly sophisticated instrumental musical forms,like concerto,symphony & sonata"%user_name)
    choise2=input("%s,Do you want to change topic or leave"%user_name)
    if choise2=="change topic":
        ask_topic(user_name)
    if choise2=="Leave" or "leave":
        goodbye(user_name)
def neo_classical(user_name):
    print("%s,it was a twentieth century developement,particularly popular in the period between the two world wars"%user_name)
    list3=["yes","sure","for sure","ok","cool","thanks","thank you"]
    list4=["no","no,thanks","I don´t want to "]
    answer3=input("%s,Would you like to know about classical?"%user_name)
    if answer3 in  list3:
        classical(user_name)
    if answer3 in  list4:
        choise3=input("%s,Do you want to change topic or leave"%user_name)
        if choise3=="change topic":
            ask_topic(user_name)
        if choise3=="Leave"or "leave":
            goodbye(user_name)
    
def goodbye(user_name):
    print("%s,Have a nice day"%user_name)
welcome()
