# %%
import skimage
print(skimage.__version__)
# Out:
# 0.17.2

# %%
import random

# %%
import matplotlib

# %%
import numpy as np
from matplotlib import pyplot as plt

random_image=np.random.random([500,500])

plt.imshow(random_image,cmap='winter')
plt.colorbar();

# %%
from skimage import data
camera=data.camera()
type(camera)
camera.shape
# Out:
# (512, 512)

# %%
coins=data.coins()
from skimage import filters
